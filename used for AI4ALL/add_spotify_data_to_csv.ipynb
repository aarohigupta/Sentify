# %%
pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 138 kB 12.7 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.0 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import numpy as np

# %%
credentials = json.load(open('/content/drive/MyDrive/authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
df = pd.read_csv('/content/drive/MyDrive/muse_spotify.csv',engine='python')

# %%
df.shape
# Out:
# (61630, 12)

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'lastfm_url',
#  'track',
#  'artist',
#  'seeds',
#  'number_of_emotion_tags',
#  'valence_tags',
#  'arousal_tags',
#  'dominance_tags',
#  'mbid',
#  'spotify_id',
#  'genre']

# %%
df = df.drop(columns=['Unnamed: 0','lastfm_url', 'valence_tags', 'arousal_tags', 'dominance_tags', 'mbid', 'genre'])

# %%
df
# Out:
#                                   track            artist  \
# 0                      'Till I Collapse            Eminem
# 1                             St. Anger         Metallica
# 2                              Speedin'         Rick Ross
# 3                          Bamboo Banga            M.I.A.
# 4                            Die MF Die              Dope
# ...                                 ...               ...
# 61625                            Secret        Quietdrive
# 61626  The Last of the Rest Was the End       Medications
# 61627                         Lovechild     Daniel Lanois
# 61628                       Last Inhale            Tapage
# 61629                            Unfold  Message To Bears
#
#                                             seeds  number_of_emotion_tags  \
# 0                                  ['aggressive']                       6
# 1                                  ['aggressive']                       8
# ...

# %%
a = 365
b = 366

# %%
uhhh = 4

# %%
df_trial = df[a*100:b*100]
# print("a = " + str(a) + " b = " + str(b) + " count = " + str(count))
df_trial
id_list = df_trial['spotify_id'].tolist()
track_names = df_trial['track'].tolist()
artist_names = df_trial['artist'].tolist()
sentiments = df_trial['seeds'].tolist()
no_of_tags = df_trial['number_of_emotion_tags'].tolist()
features = sp.audio_features(id_list)

# %%
dummy_df = pd.DataFrame(data=features, columns=features[0].keys())
# se = ["none" for i in range(100)]
dummy_df['sentiments'] = "none"
dummy_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.608   0.875    8    -4.636     1       0.0796      0.003820
# 1          0.352   0.414    4    -6.600     0       0.0254      0.391000
# 2          0.368   0.538   10   -10.067     0       0.0336      0.121000
# 3          0.600   0.658    0    -5.386     1       0.0519      0.081700
# 4          0.766   0.720    1    -8.347     1       0.1540      0.293000
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.861   0.502    5    -6.558     0       0.0656      0.008200
# 96         0.549   0.436    1    -8.333     1       0.0311      0.701000
# 97         0.713   0.596    9   -13.255     1       0.0896      0.251000
# 98         0.763   0.740    6    -9.811     0       0.0322      0.000721
# 99         0.647   0.577    4   -10.320     0       0.0306      0.602000
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
print(len(features))
print(type(features))
# Out:
# 100
# <class 'list'>

# %%
count = 1
for i in range(40, 617):
  print("i is " + str(i))
  a = i
  b = i + 1
  df_trial = df[a*100:b*100]
  id_list = df_trial['spotify_id'].tolist()
  track_names = df_trial['track'].tolist()
  artist_names = df_trial['artist'].tolist()
  sentiments = df_trial['seeds'].tolist()
  no_of_tags = df_trial['number_of_emotion_tags'].tolist()
  features = sp.audio_features(id_list)
  try:
    features_df = pd.DataFrame(data=features, columns=features[0].keys())
    features_df['sentiments'] = sentiments
  except:
    features_df = dummy_df
    features_df['sentiments'] = "none"
  
  features_df['title'] = track_names
  features_df['artist'] = artist_names
  features_df['no_of_tags'] = no_of_tags
  features_df = features_df[['id', 'title', 'artist','danceability', 'energy', 'key', 'loudness',
                            'mode', 'acousticness', 'instrumentalness',
                            'liveness', 'valence', 'tempo',
                            'duration_ms', 'time_signature', 'sentiments', 'no_of_tags']]
  features_df.to_csv("data_" + str(count) + ".csv")
  if count != 10:
    count += 1
  else:
    count = 1
    df1 = pd.read_csv("/content/data_1.csv")
    df2 = pd.read_csv("/content/data_2.csv")
    df3 = pd.read_csv("/content/data_3.csv")
    df4 = pd.read_csv("/content/data_4.csv")
    df5 = pd.read_csv("/content/data_5.csv")
    df6 = pd.read_csv("/content/data_6.csv")
    df7 = pd.read_csv("/content/data_7.csv")
    df8 = pd.read_csv("/content/data_8.csv")
    df9 = pd.read_csv("/content/data_9.csv")
    df10 = pd.read_csv("/content/data_10.csv")

    merged_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])
    merged_df.to_csv("data_test_" + str((i-9) * 100) + ".csv")
# Out:
# i is 40
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'spotify_id'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
features_df
# Out:
#                         id                             title  \
# 0   2ubBqnxBNP8QpoGQ77NPuO               Rainbows (Live '01)
# 1   7piTK9aPEBxKSXdmohLyo5                          Need Air
# 2   5TApkqwgrg2A7SJY9A8V7p                            Barika
# 3   6j65BaZ1ytKVdqKGRvZnXc                      Little Wheel
# 4   12VSTLgs46Q6b62VVpq0JW                 Black Winged Bird
# 5   5rDTGIQHCuVlBf47HbIwc0                          Drifting
# 6   0zUzw1TelsSOOhM7S6Sc0l                  Three Cats Watch
# 7   5AH9Dyo9PWrPq7N8qVzc1U          The Look of Love, Part 1
# 8   4zANGx3Z3kZzrYcXftaTpt                        Borcun Yok
# 9   7ypbfg0NMXz5OIWSIxoZBw                                 y
# 10  7BHRhNMDSEFgKraNMQoBYf                     Ne connissons
# 11  0khVUh4xxnsxANPNuUvBhE                 Cat In The Corner
# 12  5Xrj4P2EVRGi5tRg941OB5                        Son Of Man
# 13  0WlqKXIDbE3qj4BNzmiECV    Mechanical Age - Sirrus' Theme
# ...

# %%
features_df.to_csv("data_" + str(count) + ".csv")
a = b
b += 1
if count != 10:
  count += 1
else:
  count = 1
  df1 = pd.read_csv("/content/data_1.csv")
  df2 = pd.read_csv("/content/data_2.csv")
  df3 = pd.read_csv("/content/data_3.csv")
  df4 = pd.read_csv("/content/data_4.csv")
  df5 = pd.read_csv("/content/data_5.csv")
  df6 = pd.read_csv("/content/data_6.csv")
  df7 = pd.read_csv("/content/data_7.csv")
  df8 = pd.read_csv("/content/data_8.csv")
  df9 = pd.read_csv("/content/data_9.csv")
  df10 = pd.read_csv("/content/data_10.csv")


  merged_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10])
  merged_df.to_csv("data_1000_" + str(uhhh) + ".csv")
  uhhh += 1

print(count)
print(uhhh)
# Out:
# 1
# 5

# %%
# !rm "/content/data_1000_13.csv"

# %%
import os

# %%
os.remove("/content/data_1000_14.csv")

# %%
for i in range(49, 359, 10):
  os.remove(f"/content/data_test_{i*100}.csv")

# %%
df1 = pd.read_csv('/content/data_4000_1.csv')

# %%
li = [df1]

# %%
for i in range(40, 610, 10):
  df = pd.read_csv(f"/content/data_test_{i*100}.csv")
  li.append(df)

# %%
type(li)
# Out:
# list

# %%
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
list(frame.columns)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0.1',
#  'Unnamed: 0.1.1',
#  'Unnamed: 0.1.1.1',
#  'id',
#  'title',
#  'artist',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'sentiments',
#  'no_of_tags']

# %%
frame = frame.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-6cf669b3835c> in <module>()
# ----> 1 frame = frame.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'])
#       2 frame
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
frame
# Out:
#                            id               title               artist  \
# 0      6NMG1f5QGi1fadM1fJdEaw                 Pig         Sparklehorse
# 1      4WZb6UurjjVs2W6ClgwirI     Hell Broke Luce            Tom Waits
# 2      6SXmPZBeILQOR5zdQbkm47       Dog Faced Boy                 Eels
# 3      4KwBfWIgYAFCQQgXTAVZyw                Feel        Stereophonics
# 4      2UXzCNvGSXfjeU5Iynwqhp         The Promise             The Cure
# ...                       ...                 ...                  ...
# 60995  62TvqP6vN10VA2Z2PXt4Tl  Trees Keep Growing            Azure Ray
# 60996  6f3ROsQr9nwzEjRN7ITIp5        Wounded Head  William Fitzsimmons
# 60997  6437L2kB4GdbDdJbXLOu3G         Friendboats         Mariee Sioux
# 60998  3KF7PrnyI0iswl5BhIIyfU                 Oh!          Micky Green
# 60999  3CXCy292csbL8S8X2DOnxT  The Christmas Song      Catherine Feeny
#
#        danceability  energy  key  loudness  mode  acousticness  \
# ...

# %%
frame.to_csv("spotify_and_muse_data.csv")
