# %% [markdown]
# Adding spotify data to already aquired muse dataset using spotipy

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (2.19.0)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (from spotipy) (2.25.1)
# Requirement already satisfied: six>=1.15.0 in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/envs/data-preprocessing/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import spotipy
# SpotifyClientCredentials to access personal data
from spotipy.oauth2 import SpotifyClientCredentials
import json
import numpy as np

# %%
# create json file with the authorization information, ie: client_id and client_secret 
# these can be found on the developers page
# open the authorization.json as json
credentials = json.load(open('authorization.json'))
# can also directly input id and secret here
# have made a different file for the sake of confidentiality
client_id = credentials['client_id']
client_secret = credentials['client_secret']

client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
df = pd.read_csv('muse_v3.csv',engine='python')
list(df.columns)
# Out:
# ['lastfm_url',
#  'track',
#  'artist',
#  'seeds',
#  'number_of_emotion_tags',
#  'valence_tags',
#  'arousal_tags',
#  'dominance_tags',
#  'mbid',
#  'spotify_id',
#  'genre']

# %%
# removing unimportant columns that wont be needed in the model
df = df.drop(columns=['lastfm_url', 'valence_tags', 'arousal_tags', 'dominance_tags', 'mbid', 'genre'])

# %%
# seeing what the dataset looks like
df
# Out:
#                                          track                       artist  \
# 0                             'Till I Collapse                       Eminem
# 1                                    St. Anger                    Metallica
# 2                                     Speedin'                    Rick Ross
# 3                                 Bamboo Banga                       M.I.A.
# 4                                   Die MF Die                         Dope
# ...                                        ...                          ...
# 89996                                   Battle  Gaby Hoffmann & Jay Duplass
# 89997  Hands Tied to the Roots of a Hemorrhage         Omar Rodriguez-Lopez
# 89998                           Crookfield Zoo                    Ace White
# 89999               Transparent (Full Version)                 Second Chyld
# 90000                                   Unfold             Message To Bears
#
#                                             seeds  number_of_emotion_tags  \
# 0                                  ['aggressive']                       6
# 1                                  ['aggressive']                       8
# 2                                  ['aggressive']                       1
# 3      ['aggressive', 'fun', 'sexy', 'energetic']                      13
# 4                                  ['aggressive']                       7
# ...                                           ...                     ...
# 89996                             ['transparent']                       1
# 89997                             ['transparent']                       4
# 89998                             ['transparent']                       1
# 89999                             ['transparent']                       1
# 90000                             ['translucent']                       2
#
#                    spotify_id
# 0      4xkOaSrkexMciUUogZKVTS
# 1      3fOc9x06lKJBhz435mInlH
# 2      3Y96xd4Ce0J47dcalLrEC8
# 3      6tqFC1DIOphJkCwrjVzPmg
# 4      5bU4KX47KqtDKKaLM4QCzh
# ...                       ...
# 89996                     NaN
# 89997                     NaN
# 89998                     NaN
# 89999                     NaN
# 90000  14BYEOeRb3jzglJmKX8eM2
#
# [90001 rows x 5 columns]

# %%
# we see that there are some songs without a spotify id, we should remove them
df = df.dropna(subset=['spotify_id'])
df
# Out:
#                                   track            artist  \
# 0                      'Till I Collapse            Eminem
# 1                             St. Anger         Metallica
# 2                              Speedin'         Rick Ross
# 3                          Bamboo Banga            M.I.A.
# 4                            Die MF Die              Dope
# ...                                 ...               ...
# 89983                            Secret        Quietdrive
# 89985  The Last of the Rest Was the End       Medications
# 89986                         Lovechild     Daniel Lanois
# 89991                       Last Inhale            Tapage
# 90000                            Unfold  Message To Bears
#
#                                             seeds  number_of_emotion_tags  \
# 0                                  ['aggressive']                       6
# 1                                  ['aggressive']                       8
# 2                                  ['aggressive']                       1
# 3      ['aggressive', 'fun', 'sexy', 'energetic']                      13
# 4                                  ['aggressive']                       7
# ...                                           ...                     ...
# 89983                             ['transparent']                       1
# 89985                             ['transparent']                       1
# 89986                             ['transparent']                       2
# 89991                             ['transparent']                       6
# 90000                             ['translucent']                       2
#
#                    spotify_id
# 0      4xkOaSrkexMciUUogZKVTS
# 1      3fOc9x06lKJBhz435mInlH
# 2      3Y96xd4Ce0J47dcalLrEC8
# 3      6tqFC1DIOphJkCwrjVzPmg
# 4      5bU4KX47KqtDKKaLM4QCzh
# ...                       ...
# 89983  2bRIsZ92JRKlvQOZlyR9CO
# 89985  7o3Np7cho9cBCrNDokxzYC
# 89986  4fVObxldDzxxRD6a5Eth9s
# 89991  5WxwRwUQ4R4L46VEm3213y
# 90000  14BYEOeRb3jzglJmKX8eM2
#
# [61630 rows x 5 columns]

# %%
# making empty dataframe to populate with spotify information of the songs from muse dataset
merged_spotify_muse = pd.DataFrame(columns=['id', 'title', 'artist','danceability', 'energy', 'key', 'loudness',
                            'mode', 'acousticness', 'instrumentalness',
                            'liveness', 'valence', 'tempo',
                            'duration_ms', 'time_signature', 'sentiments', 'no_of_tags'])
merged_spotify_muse
# Out:
# Empty DataFrame
# Columns: [id, title, artist, danceability, energy, key, loudness, mode, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature, sentiments, no_of_tags]
# Index: []

# %%
# making a dummy dataframe for 100 songs that were throwing an error while getting spotify features
df_trial = df[36500:36600]
id_list = df_trial['spotify_id'].tolist()
features = sp.audio_features(id_list)
dummy_df = pd.DataFrame(data=features, columns=features[0].keys())
dummy_df['sentiments'] = "none"
dummy_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.608   0.875    8    -4.636     1       0.0796      0.003820
# 1          0.352   0.414    4    -6.600     0       0.0254      0.391000
# 2          0.368   0.538   10   -10.067     0       0.0336      0.121000
# 3          0.600   0.658    0    -5.386     1       0.0519      0.081700
# 4          0.766   0.720    1    -8.347     1       0.1540      0.293000
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.861   0.502    5    -6.558     0       0.0656      0.008200
# 96         0.549   0.436    1    -8.333     1       0.0311      0.701000
# 97         0.713   0.596    9   -13.255     1       0.0896      0.251000
# 98         0.763   0.740    6    -9.811     0       0.0322      0.000721
# 99         0.647   0.577    4   -10.320     0       0.0306      0.602000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.002850    0.1580   0.5290  112.924  audio_features
# 1           0.008310    0.1850   0.0688   60.042  audio_features
# 2           0.794000    0.2010   0.1290  103.573  audio_features
# 3           0.000005    0.4200   0.6770  146.007  audio_features
# 4           0.000000    0.1070   0.4870  151.901  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000127    0.0659   0.6210  130.564  audio_features
# 96          0.000000    0.1310   0.2490  138.151  audio_features
# 97          0.120000    0.0641   0.2810  122.951  audio_features
# 98          0.770000    0.0848   0.8550  133.374  audio_features
# 99          0.279000    0.1230   0.8170   87.597  audio_features
#
#                         id                                   uri  \
# 0   13zEyjK3DZm0YtZObaaS1O  spotify:track:13zEyjK3DZm0YtZObaaS1O
# 1   1HTqgP13dorct3BltLaB0l  spotify:track:1HTqgP13dorct3BltLaB0l
# 2   6xKyallmbswWAQpbBV1BBz  spotify:track:6xKyallmbswWAQpbBV1BBz
# 3   6EvmFI1bV10Rtank7f1uQW  spotify:track:6EvmFI1bV10Rtank7f1uQW
# 4   2mPAAh221qDUfWOUmgY7BR  spotify:track:2mPAAh221qDUfWOUmgY7BR
# ..                     ...                                   ...
# 95  2GvaL6YMydiMkdbazcHBYi  spotify:track:2GvaL6YMydiMkdbazcHBYi
# 96  5kiMxK0Sv1z1d4q260NICr  spotify:track:5kiMxK0Sv1z1d4q260NICr
# 97  6XDLoOiCCfg1BxNcmBHyfX  spotify:track:6XDLoOiCCfg1BxNcmBHyfX
# 98  0iaijSh55qg3rGdANiVMxD  spotify:track:0iaijSh55qg3rGdANiVMxD
# 99  4KvJNNy2mnIgsGRcbvdD7E  spotify:track:4KvJNNy2mnIgsGRcbvdD7E
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/13zEyjK3DZm0...
# 1   https://api.spotify.com/v1/tracks/1HTqgP13dorc...
# 2   https://api.spotify.com/v1/tracks/6xKyallmbswW...
# 3   https://api.spotify.com/v1/tracks/6EvmFI1bV10R...
# 4   https://api.spotify.com/v1/tracks/2mPAAh221qDU...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/2GvaL6YMydiM...
# 96  https://api.spotify.com/v1/tracks/5kiMxK0Sv1z1...
# 97  https://api.spotify.com/v1/tracks/6XDLoOiCCfg1...
# 98  https://api.spotify.com/v1/tracks/0iaijSh55qg3...
# 99  https://api.spotify.com/v1/tracks/4KvJNNy2mnIg...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/13zE...       238507
# 1   https://api.spotify.com/v1/audio-analysis/1HTq...       341000
# 2   https://api.spotify.com/v1/audio-analysis/6xKy...       155707
# 3   https://api.spotify.com/v1/audio-analysis/6Evm...       208880
# 4   https://api.spotify.com/v1/audio-analysis/2mPA...       195536
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/2Gva...       238533
# 96  https://api.spotify.com/v1/audio-analysis/5kiM...       298573
# 97  https://api.spotify.com/v1/audio-analysis/6XDL...       342973
# 98  https://api.spotify.com/v1/audio-analysis/0iai...       270987
# 99  https://api.spotify.com/v1/audio-analysis/4KvJ...       280040
#
#     time_signature sentiments
# 0                4       none
# 1                4       none
# 2                4       none
# 3                4       none
# 4                4       none
# ..             ...        ...
# 95               4       none
# 96               4       none
# 97               4       none
# 98               4       none
# 99               4       none
#
# [100 rows x 19 columns]

# %%
for i in range(0, 617):
  df_trial = df[i*100:(i+1)*100]
  id_list = df_trial['spotify_id'].tolist()
  track_names = df_trial['track'].tolist()
  artist_names = df_trial['artist'].tolist()
  sentiments = df_trial['seeds'].tolist()
  no_of_tags = df_trial['number_of_emotion_tags'].tolist()
  features = sp.audio_features(id_list)
  try:
    features_df = pd.DataFrame(data=features, columns=features[0].keys())
    features_df['sentiments'] = sentiments
  except:
    features_df = dummy_df
    features_df['sentiments'] = "none"
  
  features_df['title'] = track_names
  features_df['artist'] = artist_names
  features_df['no_of_tags'] = no_of_tags
  features_df = features_df[['id', 'title', 'artist','danceability', 'energy', 'key', 'loudness',
                            'mode', 'acousticness', 'instrumentalness',
                            'liveness', 'valence', 'tempo',
                            'duration_ms', 'time_signature', 'sentiments', 'no_of_tags']]
  merged_spotify_muse = pd.concat([merged_spotify_muse, features_df])

# %%
# resetting the index of merged_spotify_muse 
merged_spotify_muse = merged_spotify_muse.reset_index(drop = True)
merged_spotify_muse = merged_spotify_muse.drop(columns=['index'])

# %%
merged_spotify_muse
# Out:
#                            id                             title  \
# 0      4xkOaSrkexMciUUogZKVTS                  'Till I Collapse
# 1      3fOc9x06lKJBhz435mInlH                         St. Anger
# 2      3Y96xd4Ce0J47dcalLrEC8                          Speedin'
# 3      6tqFC1DIOphJkCwrjVzPmg                      Bamboo Banga
# 4      5bU4KX47KqtDKKaLM4QCzh                        Die MF Die
# ...                       ...                               ...
# 61625  2bRIsZ92JRKlvQOZlyR9CO                            Secret
# 61626  7o3Np7cho9cBCrNDokxzYC  The Last of the Rest Was the End
# 61627  4fVObxldDzxxRD6a5Eth9s                         Lovechild
# 61628  5WxwRwUQ4R4L46VEm3213y                       Last Inhale
# 61629  14BYEOeRb3jzglJmKX8eM2                            Unfold
#
#                  artist  danceability  energy key  loudness mode  \
# 0                Eminem         0.548   0.847   1    -3.237    1
# 1             Metallica         0.249   0.949   2    -2.642    0
# 2             Rick Ross         0.668   0.787   1    -4.226    1
# 3                M.I.A.         0.805   0.918   9    -4.554    1
# 4                  Dope         0.657   0.960   5    -3.524    0
# ...                 ...           ...     ...  ..       ...  ...
# 61625        Quietdrive         0.396   0.915   0    -5.126    0
# 61626       Medications         0.244   0.866   2    -5.774    0
# 61627     Daniel Lanois         0.236   0.107  10   -20.091    0
# 61628            Tapage         0.542   0.909   2    -8.977    0
# 61629  Message To Bears         0.495   0.291   0   -11.355    1
#
#        acousticness  instrumentalness  liveness  valence    tempo duration_ms  \
# 0           0.06220          0.000000    0.0816   0.1000  171.447      297787
# 1           0.00131          0.022800    0.0953   0.4980  185.252      441133
# 2           0.10900          0.000000    0.2100   0.4780  100.059      204960
# 3           0.04930          0.000000    0.0691   0.7130  125.984      298360
# 4           0.00169          0.000997    0.1090   0.5670  126.020      186067
# ...             ...               ...       ...      ...      ...         ...
# 61625       0.03340          0.000000    0.1350   0.0734  167.996      258373
# 61626       0.00433          0.072200    0.0782   0.3400  144.844      324000
# 61627       0.90100          0.748000    0.1120   0.0720   79.476      516280
# 61628       0.07180          0.817000    0.1250   0.0552  160.011      324258
# 61629       0.72700          0.913000    0.0927   0.1700   96.970      268440
#
#       time_signature                                  sentiments no_of_tags
# 0                  4                              ['aggressive']          6
# 1                  4                              ['aggressive']          8
# 2                  4                              ['aggressive']          1
# 3                  4  ['aggressive', 'fun', 'sexy', 'energetic']         13
# 4                  4                              ['aggressive']          7
# ...              ...                                         ...        ...
# 61625              4                             ['transparent']          1
# 61626              3                             ['transparent']          1
# 61627              4                             ['transparent']          2
# 61628              4                             ['transparent']          6
# 61629              4                             ['translucent']          2
#
# [61630 rows x 17 columns]

# %%
# now we have the data that we want
# we should convert it to csv for future use
merged_spotify_muse.to_csv('merged_spotify_muse.csv')
